# %%
#!/usr/bin/env python
# -*-coding:utf-8-*-
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
from scipy.stats import mode
from scipy import sparse
import csv
from datetime import *
import json, random, os

from sklearn.preprocessing import *
import lightgbm as lgb
from sklearn import metrics
from sklearn.feature_selection import SelectKBest, f_classif, chi2, SelectPercentile
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, StratifiedKFold
from sklearn.externals import joblib

from utils import *
from feature1 import feaFactory, userTagsMatrix


class LgbModel:
    def __init__(self, feaName, cateFea=[], params={}):
        self.params = {
        	'task': 'train',
            'boosting_type': 'gbdt',
            'objective': 'binary',
            'metric': 'binary_logloss',
            'learning_rate': 0.05,
        	'num_leaves': 25,
            'max_depth': -1,
            
            
            # 'min_data_in_leaf': 120,
            # 'feature_fraction': 0.9,
            # 'bagging_fraction': 0.9,
        	# 'bagging_freq': 5,
            'verbose': 0,
        }
        self.params.update(**params)
        self.feaName = feaName
        self.cateFea = cateFea
        print(feaName)

    def train(self, X, y, num_round=8000, validX=None, validy=None, early_stopping=10, verbose=True, params={}):
        trainData = lgb.Dataset(X, label=y, feature_name=self.feaName, categorical_feature=self.cateFea)
        trainParam = self.params
        trainParam.update(params)
        if isinstance(validX, (pd.DataFrame, sparse.csr_matrix)):
            validData = trainData.create_valid(validX, label=validy)
            bst = lgb.train(trainParam, trainData, num_boost_round=num_round, valid_sets=validData, early_stopping_rounds=early_stopping, verbose_eval=verbose)
        else:
            bst = lgb.train(trainParam, trainData, num_boost_round=num_round, verbose_eval=verbose)
        self.bst = bst
        return bst.best_iteration

    def cv(self, X, y, nfold=5, num_round=8000, early_stopping=10, verbose=True, params={}):
        trainParam = self.params
        trainParam.update(params)
        trainData = lgb.Dataset(X, label=y, feature_name=self.feaName, categorical_feature=self.cateFea)
        result = lgb.cv(trainParam, trainData, feature_name=self.feaName, categorical_feature=self.cateFea, num_boost_round=num_round, nfold=nfold, early_stopping_rounds=early_stopping, verbose_eval=verbose)
        return result

    def predict(self, X):
        return self.bst.predict(X)

    def feaScore(self, show=True):
        scoreDf = pd.DataFrame({'fea': self.feaName, 'importance': self.bst.feature_importance()})
        scoreDf.sort_values(['importance'], ascending=False, inplace=True)
        if show:
            print(scoreDf)
        return scoreDf

    def gridSearch(self, X, y, validX, validy, nFold=5, verbose=0):
        paramsGrids = {
            'num_leaves': [5*i for i in range(2,9)],
            # 'max_depth': list(range(3,8)),
            'min_data_in_leaf': [20*i for i in range(1,10)],
            # 'bagging_fraction': [1-0.05*i for i in range(0,5)],
            # 'bagging_freq': list(range(0,11,2)),
        }
        def getEval(params):
            iter = self.train(X, y, validX=validX, validy=validy, params=params, verbose=verbose)
            return metrics.log_loss(validy, self.predict(validX)), iter
        for k,v in paramsGrids.items():
            resultDf = pd.DataFrame({k: v})
            resultDf['metric_mean'] = list(map(lambda x: getEval({k: x}), v))
            print(resultDf)
        exit()

def main():
    # 获取特征工程数据集
    if not os.path.isfile("../temp/fea1.csv"): ##？？？？？？？？？？？
        df = importDf("../data/round1_iflyad_train.txt")
        df['flag'] = 0
        predictDf = importDf("../data/round1_iflyad_test_feature.txt")
        predictDf['flag'] = -1
        originDf = pd.concat([df,predictDf], ignore_index=True)
        originDf = feaFactory(originDf)
        exportResult(originDf, "../temp/fea1.csv")  ##？？？？？？？？？？？
    else:
        originDf = pd.read_csv("../temp/fea1.csv")   ##？？？？？？？？？？？
    originDf.index = list(range(len(originDf)))
    tagsMatrix, tagsName = userTagsMatrix(originDf['user_tags'])
    print("get feature dataset: finished!")

    # 构建训练及测试数据集
    tagSelecter = SelectPercentile(chi2, percentile=50)
    tagSelecter.fit(tagsMatrix[originDf[originDf.flag>=0].index], originDf[originDf.flag>=0]['click'])
    tagsMatrix = tagSelecter.transform(tagsMatrix)
    tagsName = tagsName[tagSelecter.get_support()]
    cateFea = [
        'adid','advert_id','orderid','advert_industry_inner','campaign_id','creative_id','creative_type','creative_tp_dnf','creative_has_deeplink','creative_is_jump',
        'app_cate_id','f_channel','app_id','inner_slot_id',
        'city','province','carrier','nnt','devtype','os','osv','make','model',

        'advert_industry_inner1','creative_area',
        'slot_prefix',
        'is_wifi',
        ]
    numFea = [
        'creative_width','creative_height',

        'day','hour','date','online_days',
        'advert_showed','ad_today_num','ad_his_ctr','creative_area_today_num','creative_area_his_ctr','creative_today_num','creative_his_ctr',
        'slot_today_num','slot_his_ctr',
        'nnt_gtype','osv1','ios_osv1','android_osv1','city_today_num','city_his_ctr',
        'tags21_len','tags30_len','tagsLen10_len','tagsAg_len','tagsGd_len','tagsMz_len',
    ]
    tagFea = ['tag_'+x for x in tagsName]
    fea = cateFea + numFea + tagFea
    originDf = labelEncoding(originDf, cateFea)

    originX = sparse.hstack([sparse.csr_matrix(originDf[cateFea+numFea]), tagsMatrix], 'csr').astype('float32')
    dfX = originX[originDf[originDf.flag>=0].index]
    dfy = originDf[originDf.flag>=0]['click']
    trainX = originX[originDf[(originDf.flag>=0)&(originDf.day<6)].index]
    trainy = originDf[(originDf.flag>=0)&(originDf.day<6)]['click']
    validX = originX[originDf[(originDf.flag>=0)&(originDf.day==6)].index]
    validy = originDf[(originDf.flag>=0)&(originDf.day==6)]['click']
    testX = originX[originDf[originDf.flag==-1].index]
    # df = originDf[originDf.flag>=0]
    # trainDf = df[df.day < 6]
    # validDf = df[df.day == 6]
    # predictDf = originDf[originDf.flag==-1]

    # 训练模型
    model = LgbModel(fea, cateFea=cateFea)
    # model.gridSearch(trainX, trainy, validX, validy)
    iterNum = model.train(trainX, trainy, validX=validX, validy=validy)
    model.train(dfX, dfy, num_round=iterNum)
    model.feaScore()

    # 预测结果
    predictDf = pd.DataFrame({'instance_id':originDf[originDf.flag==-1]['instance_id']})
    predictDf['predicted_score'] = model.predict(testX)
    print(predictDf[['instance_id','predicted_score']].describe())
    print(predictDf[['instance_id','predicted_score']].head())
    exportResult(predictDf[['instance_id','predicted_score']], "../result/lgb1.csv")

if __name__ == '__main__':
    startTime = datetime.now()
    main()
    print('total time:', datetime.now() - startTime)
# Out:
# get feature dataset: finished!
# ['adid', 'advert_id', 'orderid', 'advert_industry_inner', 'campaign_id', 'creative_id', 'creative_type', 'creative_tp_dnf', 'creative_has_deeplink', 'creative_is_jump', 'app_cate_id', 'f_channel', 'app_id', 'inner_slot_id', 'city', 'province', 'carrier', 'nnt', 'devtype', 'os', 'osv', 'make', 'model', 'advert_industry_inner1', 'creative_area', 'slot_prefix', 'is_wifi', 'creative_width', 'creative_height', 'day', 'hour', 'date', 'online_days', 'advert_showed', 'ad_today_num', 'ad_his_ctr', 'creative_area_today_num', 'creative_area_his_ctr', 'creative_today_num', 'creative_his_ctr', 'slot_today_num', 'slot_his_ctr', 'nnt_gtype', 'osv1', 'ios_osv1', 'android_osv1', 'city_today_num', 'city_his_ctr', 'tags21_len', 'tags30_len', 'tagsLen10_len', 'tagsAg_len', 'tagsGd_len', 'tagsMz_len', 'tag_2100000', 'tag_2100003', 'tag_2100004', 'tag_2100010', 'tag_2100013', 'tag_2100017', 'tag_2100019', 'tag_2100022', 'tag_2100024', 'tag_2100025', 'tag_2100027', 'tag_2100029', 'tag_2100030', 'tag_2100031', 'tag_2100043', 'tag_2100044', 'tag_2100045', 'tag_2100078', 'tag_2100079', 'tag_2100080', 'tag_2100084', 'tag_2100085', 'tag_2100086', 'tag_2100088', 'tag_2100091', 'tag_2100092', 'tag_2100094', 'tag_2100095', 'tag_2100105', 'tag_2100108', 'tag_2100110', 'tag_2100113', 'tag_2100122', 'tag_2100124', 'tag_2100125', 'tag_2100126', 'tag_2100127', 'tag_2100130', 'tag_2100131', 'tag_2100132', 'tag_2100133', 'tag_2100136', 'tag_2100138', 'tag_2100141', 'tag_2100142', 'tag_2100144', 'tag_2100148', 'tag_2100150', 'tag_2100151', 'tag_2100152', 'tag_2100192', 'tag_2100193', 'tag_2100197', 'tag_2100198', 'tag_2100235', 'tag_2100237', 'tag_2100238', 'tag_2100239', 'tag_2100254', 'tag_2100255', 'tag_2100262', 'tag_2100265', 'tag_2100276', 'tag_2100284', 'tag_2100298', 'tag_2100308', 'tag_2100320', 'tag_2100330', 'tag_2100345', 'tag_2100353', 'tag_2100363', 'tag_2100373', 'tag_2100387', 'tag_2100393', 'tag_2100400', 'tag_2100406', 'tag_2100413', 'tag_2100417', 'tag_2100429', 'tag_2100439', 'tag_2100451', 'tag_2100454', 'tag_2100460', 'tag_2100463', 'tag_2100467', 'tag_2100469', 'tag_2100474', 'tag_2100477', 'tag_2100480', 'tag_2100491', 'tag_2100495', 'tag_2100497', 'tag_2100501', 'tag_2100520', 'tag_2100524', 'tag_2100526', 'tag_2100533', 'tag_2100541', 'tag_2100554', 'tag_2100572', 'tag_2100577', 'tag_2100581', 'tag_2100595', 'tag_2100628', 'tag_2100650', 'tag_2100678', 'tag_2100706', 'tag_2100719', 'tag_2100727', 'tag_2100732', 'tag_2100736', 'tag_2100746', 'tag_2100765', 'tag_2100768', 'tag_2100782', 'tag_2100789', 'tag_2100802', 'tag_2100819', 'tag_2100835', 'tag_2100838', 'tag_2100847', 'tag_2100852', 'tag_2100862', 'tag_2100871', 'tag_2100876', 'tag_2100881', 'tag_2100889', 'tag_2100895', 'tag_2100909', 'tag_2100935', 'tag_2100947', 'tag_2100953', 'tag_2100963', 'tag_2100969', 'tag_2100978', 'tag_2100984', 'tag_2100992', 'tag_2101000', 'tag_2101006', 'tag_2101018', 'tag_2101029', 'tag_2101040', 'tag_2101047', 'tag_2101048', 'tag_2101058', 'tag_2101075', 'tag_2101087', 'tag_2101099', 'tag_2101106', 'tag_2101117', 'tag_2101137', 'tag_2101148', 'tag_2101154', 'tag_2101161', 'tag_2101172', 'tag_2101188', 'tag_2101199', 'tag_2101230', 'tag_2101248', 'tag_2101264', 'tag_2101283', 'tag_2101322', 'tag_2101340', 'tag_2101347', 'tag_2101363', 'tag_2101374', 'tag_3001737', 'tag_3001745', 'tag_3001747', 'tag_3001757', 'tag_3001765', 'tag_3001771', 'tag_3001773', 'tag_3001779', 'tag_3001785', 'tag_3001793', 'tag_3001797', 'tag_3001799', 'tag_3001851', 'tag_3001853', 'tag_3001857', 'tag_3001865', 'tag_3001873', 'tag_3001879', 'tag_3001893', 'tag_3001919', 'tag_3001925', 'tag_3001927', 'tag_3001937', 'tag_3001939', 'tag_3001941', 'tag_3001943', 'tag_3001949', 'tag_3001951', 'tag_3001953', 'tag_3001975', 'tag_3002015', 'tag_3002033', 'tag_3002041', 'tag_3002043', 'tag_3002053', 'tag_3002055', 'tag_3002069', 'tag_3002089', 'tag_3002093', 'tag_3002095', 'tag_3002109', 'tag_3002115', 'tag_3002119', 'tag_3002195', 'tag_3002199', 'tag_3002205', 'tag_3002245', 'tag_3002247' ...
# D:\Anaconda\lib\site-packages\lightgbm\basic.py:1040: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# D:\Anaconda\lib\site-packages\lightgbm\basic.py:1042: UserWarning: categorical_feature in Dataset is overridden. New categorical_feature is ['adid', 'advert_id', 'advert_industry_inner', 'advert_industry_inner1', 'app_cate_id', 'app_id', 'campaign_id', 'carrier', 'city', 'creative_area', 'creative_has_deeplink', 'creative_id', 'creative_is_jump', 'creative_tp_dnf', 'creative_type', 'devtype', 'f_channel', 'inner_slot_id', 'is_wifi', 'make', 'model', 'nnt', 'orderid', 'os', 'osv', 'province', 'slot_prefix']
#   warnings.warn('categorical_feature in Dataset is overridden. New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# D:\Anaconda\lib\site-packages\lightgbm\basic.py:685: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [1]	valid_0's binary_logloss: 0.503365
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's binary_logloss: 0.497022
# [3]	valid_0's binary_logloss: 0.491331
# [4]	valid_0's binary_logloss: 0.486141
# [5]	valid_0's binary_logloss: 0.481547
# [6]	valid_0's binary_logloss: 0.477333
# [7]	valid_0's binary_logloss: 0.4735
# [8]	valid_0's binary_logloss: 0.469911
# [9]	valid_0's binary_logloss: 0.466692
# [10]	valid_0's binary_logloss: 0.46376
# [11]	valid_0's binary_logloss: 0.461017
# [12]	valid_0's binary_logloss: 0.458332
# [13]	valid_0's binary_logloss: 0.456042
# [14]	valid_0's binary_logloss: 0.453979
# [15]	valid_0's binary_logloss: 0.451921
# [16]	valid_0's binary_logloss: 0.449953
# [17]	valid_0's binary_logloss: 0.448278
# [18]	valid_0's binary_logloss: 0.446745
# [19]	valid_0's binary_logloss: 0.445296
# [20]	valid_0's binary_logloss: 0.443979
# [21]	valid_0's binary_logloss: 0.4427
# [22]	valid_0's binary_logloss: 0.441465
# [23]	valid_0's binary_logloss: 0.440344
# [24]	valid_0's binary_logloss: 0.439325
# [25]	valid_0's binary_logloss: 0.43838
# [26]	valid_0's binary_logloss: 0.437473
# [27]	valid_0's binary_logloss: 0.43662
# [28]	valid_0's binary_logloss: 0.435836
# [29]	valid_0's binary_logloss: 0.435102
# [30]	valid_0's binary_logloss: 0.434446
# [31]	valid_0's binary_logloss: 0.433792
# [32]	valid_0's binary_logloss: 0.433198
# [33]	valid_0's binary_logloss: 0.43266
# [34]	valid_0's binary_logloss: 0.432156
# [35]	valid_0's binary_logloss: 0.431671
# [36]	valid_0's binary_logloss: 0.431235
# [37]	valid_0's binary_logloss: 0.43086
# [38]	valid_0's binary_logloss: 0.430437
# [39]	valid_0's binary_logloss: 0.430051
# [40]	valid_0's binary_logloss: 0.429729
# [41]	valid_0's binary_logloss: 0.429386
# [42]	valid_0's binary_logloss: 0.429101
# [43]	valid_0's binary_logloss: 0.428829
# [44]	valid_0's binary_logloss: 0.428532
# [45]	valid_0's binary_logloss: 0.428288
# [46]	valid_0's binary_logloss: 0.428057
# [47]	valid_0's binary_logloss: 0.42785
# [48]	valid_0's binary_logloss: 0.427613
# [49]	valid_0's binary_logloss: 0.427407
# [50]	valid_0's binary_logloss: 0.427212
# [51]	valid_0's binary_logloss: 0.427068
# [52]	valid_0's binary_logloss: 0.426903
# [53]	valid_0's binary_logloss: 0.426773
# [54]	valid_0's binary_logloss: 0.426642
# [55]	valid_0's binary_logloss: 0.426492
# [56]	valid_0's binary_logloss: 0.426348
# [57]	valid_0's binary_logloss: 0.426229
# [58]	valid_0's binary_logloss: 0.426129
# [59]	valid_0's binary_logloss: 0.426021
# [60]	valid_0's binary_logloss: 0.425928
# [61]	valid_0's binary_logloss: 0.425846
# [62]	valid_0's binary_logloss: 0.425785
# [63]	valid_0's binary_logloss: 0.425705
# [64]	valid_0's binary_logloss: 0.425635
# [65]	valid_0's binary_logloss: 0.425548
# [66]	valid_0's binary_logloss: 0.425491
# [67]	valid_0's binary_logloss: 0.42542
# [68]	valid_0's binary_logloss: 0.42537
# [69]	valid_0's binary_logloss: 0.425303
# [70]	valid_0's binary_logloss: 0.42525
# [71]	valid_0's binary_logloss: 0.425199
# [72]	valid_0's binary_logloss: 0.425166
# [73]	valid_0's binary_logloss: 0.425131
# [74]	valid_0's binary_logloss: 0.425107
# [75]	valid_0's binary_logloss: 0.425075
# [76]	valid_0's binary_logloss: 0.425046
# [77]	valid_0's binary_logloss: 0.425016
# [78]	valid_0's binary_logloss: 0.424993
# [79]	valid_0's binary_logloss: 0.424919
# [80]	valid_0's binary_logloss: 0.424898
# [81]	valid_0's binary_logloss: 0.424877
# [82]	valid_0's binary_logloss: 0.42486
# [83]	valid_0's binary_logloss: 0.424841
# [84]	valid_0's binary_logloss: 0.424822
# [85]	valid_0's binary_logloss: 0.424804
# [86]	valid_0's binary_logloss: 0.424753
# [87]	valid_0's binary_logloss: 0.424744
# [88]	valid_0's binary_logloss: 0.42471
# [89]	valid_0's binary_logloss: 0.424702
# [90]	valid_0's binary_logloss: 0.42468
# [91]	valid_0's binary_logloss: 0.424682
# [92]	valid_0's binary_logloss: 0.424651
# [93]	valid_0's binary_logloss: 0.424635
# [94]	valid_0's binary_logloss: 0.42463
# [95]	valid_0's binary_logloss: 0.424631
# [96]	valid_0's binary_logloss: 0.424627
# [97]	valid_0's binary_logloss: 0.424615
# [98]	valid_0's binary_logloss: 0.424616
# [99]	valid_0's binary_logloss: 0.42461
# [100]	valid_0's binary_logloss: 0.424595
# [101]	valid_0's binary_logloss: 0.424591
# [102]	valid_0's binary_logloss: 0.424596
# [103]	valid_0's binary_logloss: 0.424591
# [104]	valid_0's binary_logloss: 0.424579
# [105]	valid_0's binary_logloss: 0.42459
# [106]	valid_0's binary_logloss: 0.424573
# [107]	valid_0's binary_logloss: 0.424576
# [108]	valid_0's binary_logloss: 0.424571
# [109]	valid_0's binary_logloss: 0.424586
# [110]	valid_0's binary_logloss: 0.424592
# [111]	valid_0's binary_logloss: 0.424586
# [112]	valid_0's binary_logloss: 0.424574
# [113]	valid_0's binary_logloss: 0.424564
# [114]	valid_0's binary_logloss: 0.424551
# [115]	valid_0's binary_logloss: 0.424555
# [116]	valid_0's binary_logloss: 0.424556
# [117]	valid_0's binary_logloss: 0.424544
# [118]	valid_0's binary_logloss: 0.424537
# [119]	valid_0's binary_logloss: 0.424543
# [120]	valid_0's binary_logloss: 0.424537
# [121]	valid_0's binary_logloss: 0.42453
# [122]	valid_0's binary_logloss: 0.424526
# [123]	valid_0's binary_logloss: 0.424531
# [124]	valid_0's binary_logloss: 0.42453
# [125]	valid_0's binary_logloss: 0.424539
# [126]	valid_0's binary_logloss: 0.424535
# [127]	valid_0's binary_logloss: 0.424537
# [128]	valid_0's binary_logloss: 0.42455
# [129]	valid_0's binary_logloss: 0.424544
# [130]	valid_0's binary_logloss: 0.424556
# [131]	valid_0's binary_logloss: 0.424534
# [132]	valid_0's binary_logloss: 0.424541
# Early stopping, best iteration is:
# [122]	valid_0's binary_logloss: 0.424526
#                  fea  importance
# 22             model        1234
# 14              city         355
# 0               adid         260
# 13     inner_slot_id         225
# 2            orderid         151
# 21              make         116
# 5        creative_id          92
# 20               osv          71
# 12            app_id          67
# 7    creative_tp_dnf          47
# 11         f_channel          37
# 4        campaign_id          35
# 35        ad_his_ctr          26
# 363      tag_3003123          20
# 1          advert_id          20
# 460      tag_3003783          17
# 482      tag_3003939          15
# 492      tag_3004105          13
# 41      slot_his_ctr          12
# 511      tag_3004262          11
# 526      tag_3004376           9
# 15          province           9
# 516      tag_3004294           8
# 535      tag_3004504           7
# 90       tag_2100127           6
# 528      tag_3004406           6
# 534      tag_3004500           6
# 369      tag_3003145           6
# 536      tag_3004506           6
# 42         nnt_gtype           5
# ..               ...         ...
# 224      tag_3001765           0
# 223      tag_3001757           0
# 222      tag_3001747           0
# 221      tag_3001745           0
# 220      tag_3001737           0
# 219      tag_2101374           0
# 218      tag_2101363           0
# 217      tag_2101347           0
# 216      tag_2101340           0
# 215      tag_2101322           0
# 214      tag_2101283           0
# 213      tag_2101264           0
# 212      tag_2101248           0
# 211      tag_2101230           0
# 210      tag_2101199           0
# 209      tag_2101188           0
# 208      tag_2101172           0
# 207      tag_2101161           0
# 206      tag_2101154           0
# 205      tag_2101148           0
# 204      tag_2101137           0
# 203      tag_2101117           0
# 202      tag_2101106           0
# 201      tag_2101099           0
# 200      tag_2101087           0
# 199      tag_2101075           0
# 198      tag_2101058           0
# 197      tag_2101048           0
# 196      tag_2101047           0
# 557       tag_mzgd_2           0
#
# [558 rows x 2 columns]
#         instance_id  predicted_score
# count  4.002400e+04     40024.000000
# mean   4.620362e+18         0.213894
# std    2.661785e+18         0.166057
# min    7.622589e+13         0.002279
# 25%    2.332097e+18         0.046565
# 50%    4.620495e+18         0.225291
# 75%    6.925314e+18         0.305011
# max    9.223342e+18         0.774172
#                  instance_id  predicted_score
# 1001650  6930856710792380886         0.134136
# 1001651  5460409694420131920         0.332195
# 1001652   982813438159141507         0.120573
# 1001653   529991959116679673         0.191068
# 1001654  5357053206615171780         0.003216
# total time: 0:12:09.039843
